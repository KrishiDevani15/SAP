# %% [markdown]
# #  EDUNET FOUNDATION - Self Practice Excercise

# %% [markdown]
# ## Lab 1
# ## Problem Statement

# %% [markdown]
# ### ""For extended data of CO2 emission ("Excercise_Data_1.csv").
# ### Company needs a multiple regression model to predict the emission generate from a newly produced car.

# %%
# Importing the required library

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.preprocessing import StandardScaler,MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import RFE
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression,Ridge,Lasso
from sklearn.metrics import r2_score,mean_squared_error
from sklearn import metrics

# %%
df=pd.read_csv("FuelConsumption.csv")
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-1aa96cec0955> in <cell line: 1>()
# ----> 1 df=pd.read_csv("FuelConsumption.csv")
#       2 df
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
print(df.info())
print("\n")
print(df.describe())
df.columns
cdf=df[['MAKE','MODEL','VEHICLE CLASS','ENGINE SIZE','CYLINDERS','TRANSMISSION','FUEL','FUEL CONSUMPTION','COEMISSIONS ']]  ### Selected appended and DataFrame create
cdf.head()

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder_MAKE = LabelEncoder()
label_encoder_MODEL = LabelEncoder()
label_encoder_VEHICLE_CLASS = LabelEncoder()
label_encoder_TRANSMISSION = LabelEncoder()
label_encoder_FUEL = LabelEncoder()

# %%
df["MAKE"] = label_encoder_MAKE.fit_transform(df['MAKE'])
df["MODEL"] = label_encoder_MODEL.fit_transform(df['MODEL'])
df["VEHICLE CLASS"] = label_encoder_VEHICLE_CLASS.fit_transform(df['VEHICLE CLASS'])
df["TRANSMISSION"] = label_encoder_TRANSMISSION.fit_transform(df['TRANSMISSION'])
df["FUEL"] = label_encoder_FUEL.fit_transform(df['FUEL'])

# %%
X = df[['MAKE','MODEL','VEHICLE CLASS','ENGINE SIZE','CYLINDERS','TRANSMISSION','FUEL','FUEL CONSUMPTION']]
X = X.values
X
y = df.iloc[:,-1]
